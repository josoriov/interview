# %%
float("-infinity")
# Out:
# -inf

# %%
{
    1: "abc",
    2: "def",
    3: "ghi"
}.values()
# Out:
# dict_values(['abc', 'def', 'ghi'])

# %%
"abba"[1:2]
# Out:
# 'b'

# %%
int("123")
# Out:
# 123
